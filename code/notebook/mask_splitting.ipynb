# %%
import h5py
import cv2
import matplotlib.pyplot as plt
import numpy as np
import imageio
import os
import pandas as pd

# %%
train_df = pd.read_csv('../../data/train_fold_v6.csv')

# %%
train_df.head()
# Out:
#    Unnamed: 0.1                                    ID  Label  0  1  2  3  4  \
# 0             0  5c27f04c-bb99-11e8-b2b9-ac1f6b6435d0  8|5|0  1  0  0  0  0
# 1             1  5fb643ee-bb99-11e8-b2b9-ac1f6b6435d0   14|0  1  0  0  0  0
# 2             2  60b57878-bb99-11e8-b2b9-ac1f6b6435d0    6|1  0  1  0  0  0
# 3             3  5c1a898e-bb99-11e8-b2b9-ac1f6b6435d0  16|10  0  0  0  0  0
# 4             5  5e22a522-bb99-11e8-b2b9-ac1f6b6435d0      0  1  0  0  0  0
#
#    5  6  ...  13  14  15  16  17  18  fold  total_cell_mask  selected_cells  \
# 0  1  0  ...   0   0   0   0   0   0     2                8               7
# 1  0  0  ...   0   1   0   0   0   0     0               15              15
# 2  0  1  ...   0   0   0   0   0   0     1               17              16
# 3  0  0  ...   0   0   0   1   0   0     1               17              17
# 4  0  0  ...   0   0   0   0   0   0     1               10               9
#
#    is_single
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ## this is important

# %%
im_tok = '0a83291a-bbc5-11e8-b2bc-ac1f6b6435d0'

img_red    = np.expand_dims(imageio.imread(os.path.join('../../data/train',f'{im_tok}_red.png')), axis = -1)
img_yellow = np.expand_dims(imageio.imread(os.path.join('../../data/train',f'{im_tok}_yellow.png')), axis = -1)
img_green  = np.expand_dims(imageio.imread(os.path.join('../../data/train',f'{im_tok}_green.png')), axis = -1)
img_blue   = np.expand_dims(imageio.imread(os.path.join('../../data/train',f'{im_tok}_blue.png')), axis = -1)
image = np.concatenate([img_red, img_yellow,  img_blue], axis=-1)
img_mask = np.load(os.path.join('../../data/hpa_cell_mask',f'{im_tok}.npz'))['arr_0'].astype(np.uint8)
img_nu_mask = np.load(os.path.join('../../data/hpa_nuclei_mask',f'{im_tok}.npz'))['arr_0'].astype(np.uint8)

# %%
plt.imshow(image)

# %%
plt.imshow(img_mask)

# %%
plt.imshow(img_nu_mask)

# %% [markdown]
# ## now lets see how it goes

# %%
im_tok = '5fb643ee-bb99-11e8-b2b9-ac1f6b6435d0'

img_red    = np.expand_dims(imageio.imread(os.path.join('../../data/train',f'{im_tok}_red.png')), axis = -1)
img_yellow = np.expand_dims(imageio.imread(os.path.join('../../data/train',f'{im_tok}_yellow.png')), axis = -1)
img_green  = np.expand_dims(imageio.imread(os.path.join('../../data/train',f'{im_tok}_green.png')), axis = -1)
img_blue   = np.expand_dims(imageio.imread(os.path.join('../../data/train',f'{im_tok}_blue.png')), axis = -1)
image = np.concatenate([img_red, img_yellow,  img_blue], axis=-1)
img_mask = np.load(os.path.join('../../data/hpa_cell_mask',f'{im_tok}.npz'))['arr_0'].astype(np.uint8)
img_nu_mask = np.load(os.path.join('../../data/hpa_nuclei_mask',f'{im_tok}.npz'))['arr_0'].astype(np.uint8)

# %%
plt.imshow(image)

# %%
plt.imshow(img_mask)

# %%
plt.imshow(img_nu_mask)
