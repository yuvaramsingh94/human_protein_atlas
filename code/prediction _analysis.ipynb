# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_2_3_8_oof_seed_1 = pd.read_csv('../weights/version_v2_3_11_5_2/oof_seed_1.csv')
train_df = pd.read_csv('../data/train_fold_v6.csv')

# %%
print('OOF ',df_2_3_8_oof_seed_1.shape)
print('train_df ',train_df.shape)
df_2_3_8_oof_seed_1.head()
# Out:
# OOF  (12257, 44)
# train_df  (20523, 25)
#                                      ID  Label  0  1  2  3  4  5  6  7  ...  \
# 0  5c27f04c-bb99-11e8-b2b9-ac1f6b6435d0  8|5|0  1  0  0  0  0  1  0  0  ...
# 1  60b57878-bb99-11e8-b2b9-ac1f6b6435d0    6|1  0  1  0  0  0  0  1  0  ...
# 2  5b88d5e8-bb99-11e8-b2b9-ac1f6b6435d0   14|2  0  0  1  0  0  0  0  0  ...
# 3  6afe63b2-bb99-11e8-b2b9-ac1f6b6435d0      8  0  0  0  0  0  0  0  0  ...
# 4  71c6077c-bb99-11e8-b2b9-ac1f6b6435d0      7  0  0  0  0  0  0  0  1  ...
#
#      pred_9   pred_10   pred_11   pred_12   pred_13   pred_14   pred_15  \
# 0  0.077673  0.033403  0.045792  0.111453  0.109643  0.154261  0.061003
# 1  0.060396  0.060381  0.039187  0.099674  0.128639  0.139191  0.029303
# 2  0.021355  0.064723  0.021310  0.106241  0.109995  0.547910  0.032913
# 3  0.046954  0.045501  0.041480  0.103798  0.097034  0.412365  0.025777
# 4  0.157079  0.020105  0.011578  0.106998  0.122936  0.066420  0.013636
#
#     pred_16   pred_17   pred_18
# ...

# %%
act_label = [str(i) for i in range(19)]
pred_label = [f'pred_{i}' for i in range(19)]
df_labels_actual = df_2_3_8_oof_seed_1[act_label]
df_labels_pred = df_2_3_8_oof_seed_1[pred_label]
coocc = df_labels_actual.T.dot(df_labels_pred)

# %%
coocc
# Out:
#          pred_0      pred_1      pred_2      pred_3      pred_4      pred_5  \
# 0   2504.754499  505.294442  648.021239  457.154386  436.925721  833.251358
# 1    235.649323  374.109809   83.801809   35.590857   40.868820   83.988102
# 2    459.256751  125.561185  666.056969  154.258535   97.753209  167.607153
# 3    246.413056   44.697224  115.504514  329.818625   58.607010   93.575712
# 4    185.116132   50.459001   60.550516   59.030297  419.008882  111.784151
# 5    336.630995   71.038901   98.818060   88.814601   96.924613  448.478525
# 6     79.282127   46.851267   46.166705   34.749019   24.768528   49.372647
# 7    329.538978   64.313917   89.119178   60.584086   60.734842  136.667937
# 8    139.275482   44.729540   50.504620   40.271786   46.221398   62.177546
# 9    178.375266   46.173404   56.583178   43.269577   59.212413   79.296201
# 10   115.932303   26.429902   49.725081   40.557158   41.209784   47.829055
# ...

# %%
coocc
# Out:
#          pred_0      pred_1      pred_2      pred_3      pred_4      pred_5  \
# 0   2539.871216  445.850254  705.053887  508.938090  300.863642  609.352946
# 1    205.066532  433.525882   89.848677   40.084942   29.070731   52.193013
# 2    416.125705  111.524308  737.597948  156.758669   60.784946  105.932732
# 3    213.131929   26.233813   92.514065  402.270720   37.891837   55.448523
# 4    145.358377   43.611126   69.514510   59.195138  434.704688   79.908002
# 5    308.891736   63.439996  107.834008  103.274077   74.664460  418.287333
# 6     48.935618   33.796014   49.395963   33.360135   13.948643   28.407325
# 7    274.434378   49.445071   86.183023   79.298729   43.179064   91.915031
# 8    109.609026   28.673866   43.328336   34.364262   29.836077   39.042447
# 9    141.630346   25.942945   46.041882   37.559056   39.366528   46.523646
# 10    90.604996   13.858562   49.311004   40.648963   21.041795   21.496842
# ...

# %%
fig, ax = plt.subplots(figsize=(16, 13))
sns.heatmap(coocc, cmap="Blues", linewidth=0.3, cbar_kws={"shrink": .8})
title = 'How often do individual classes cooccur in the train set?\n(Single class occurrences are on the diagonal)\n'
plt.title(title, loc='center', fontsize=18)
plt.show()
